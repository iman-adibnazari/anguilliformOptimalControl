# %%
import pyvista as pv
import meshio
import numpy as np
import psycopg2
import hdf5storage
import h5py
import pickle
import logging
from sys import getsizeof
from dotenv import dotenv_values

pv.global_theme.transparent_background = True


config = dotenv_values("../.env")
# Filepaths for script
initMeshPath = config["currentDirectory"] +"meshes/fullAssemblyContiguous/fullFishContiguous.msh"
tempMeshPath = config["backupDirectory"] + "data/visualizations/holdpls/"
outputPath = config["currentDirectory"] + "data/visualizations/controlExperiments/"

# %%
# Helper functions for working with database
def get_db_connection():
    conn = psycopg2.connect(
        dbname='simDB',
        user='user',
        password='password',
        host='localhost',
        port='5432'
    )
    return conn

def fetch_trial_data_singleTimestep(conn, trial_id, n=1, start_timestep=0, num_timesteps=500):
    try:
        cur = conn.cursor()
        
        # Fetch data for the given trial_id starting from start_timestep
        query = '''
        SELECT timestep, simulation_time, input_data, output_data, state_data, y_ref, x_hat
        FROM simulation_data
        WHERE trial_id = %s AND timestep >= %s AND timestep < %s
        ORDER BY timestep ASC;
        '''
        cur.execute(query, (trial_id, start_timestep, start_timestep + 1))
        rows = cur.fetchall()
        
        # Deserialize data
        data = []
        for row in rows:
            timestep, simulation_time, input_data_bin, output_data_bin, state_data_bin, y_ref_bin, x_hat_bin = row
            input_data = np.array(pickle.loads(input_data_bin))
            output_data = np.array(pickle.loads(output_data_bin))
            state_data = np.array(pickle.loads(state_data_bin))
            y_ref = np.array(pickle.loads(y_ref_bin))
            x_hat = np.array(pickle.loads(x_hat_bin))
            data.append((timestep, simulation_time, input_data, output_data,state_data, y_ref, x_hat))
        
        cur.close()
        return data
    except Exception as e:
        print(f"Error fetching data for trial_id {trial_id}: {e}")
        return None

# %%
# Trial Parameters
trial_ids = [192]
timesteps = 500

# %%
### Get offsets for reference trajectory
# Load data from database
conn = get_db_connection()
data = fetch_trial_data_singleTimestep(conn, trial_ids[0], 1, start_timestep=0, num_timesteps=1)
conn.close()
timestep, simulation_time, input_data, output_data, state_data, y_ref, x_hat = data[0]
# Get the reference trajectory
refOffsets = np.copy(output_data)

# %%
# ###### Generate mp4 of fish swimming in isometric view along with reference trajectory for specified trials
# for trial_id in trial_ids:
#     # create plotter object
#     plotter = pv.Plotter()
#     # Open a mp4
#     plotter.open_movie(outputPath + f"Trial{trial_id}_isoView.mp4", framerate = 100, quality=7)
#     # Iterate through timesteps and add frames
#     for i in range(timesteps):
#         print(f"Trial {trial_id}, Timestep {i}")
#         ### Make surface from desired reference trajectory
#         # Load data from database
#         conn = get_db_connection()
#         data = fetch_trial_data_singleTimestep(conn, trial_id, 1, start_timestep=i, num_timesteps=1)
#         conn.close()
#         timestep, simulation_time, input_data, output_data, state_data, y_ref, x_hat = data[0]
#         # Check shape of reference trajectory
#         uncenteredRefTraj=y_ref + refOffsets
#         # Turn reference trajectory from 40x1 to 20x2 array by taking every other point 
#         x_refs = uncenteredRefTraj[::2]
#         z_refs = uncenteredRefTraj[1::2]
#         referenceCurve = np.column_stack((x_refs, np.zeros(np.size(x_refs)), z_refs))
#         # print(np.shape(referenceCurve))
#         path = referenceCurve
#         offsetPath = np.copy(path)
#         offsetPath[:, 1] = offsetPath[:, 1] - 102
#         #### Draw Surface for reference trajectory
#         # Number of samples (in depth dir) and number of points along centerline 
#         nsamples = 3
#         ntraces = 20  
#         # Define the Z spacing of your 2D section
#         z_spacing = 50
#         # Create structured points draping down from the path
#         points = np.repeat(path, nsamples, axis=0)
#         # repeat the Z locations across
#         tp = np.arange(0, z_spacing * nsamples, z_spacing)
#         # Offset the Z locations 
#         tp = path[:, 1][:, None] - tp
#         points[:, 1] = tp.ravel()
#         #Make a StructuredGrid from the structured points
#         grid = pv.StructuredGrid()
#         grid.points = points
#         grid.dimensions = nsamples, ntraces, 1
#         # Add the data array - note the ordering
#         grid["values"] = np.ones((nsamples, ntraces), dtype=np.float64).ravel(order="F")

#         ### Plot actual centerline from output_data
#         # Load data from database
#         conn = get_db_connection()
#         data = fetch_trial_data_singleTimestep(conn, trial_id, 1, start_timestep=i, num_timesteps=1)
#         conn.close()
#         timestep, simulation_time, input_data, output_data, state_data, y_ref, x_hat = data[0]
#         # Check shape of output data
#         uncenteredOutputTraj=output_data
#         # Turn output trajectory from 40x1 to 20x2 array by taking every other point
#         x_outs = uncenteredOutputTraj[::2]
#         z_outs = uncenteredOutputTraj[1::2]
#         outputCurve = np.column_stack((x_outs, np.zeros(np.size(x_outs)), z_outs))
#         # print(np.shape(outputCurve))
#         offsetOutputCurve = np.copy(outputCurve)
#         offsetOutputCurve[:, 1] = offsetOutputCurve[:, 1] - 102


        

#         # load mesh from .vtu file in tempMeshPath
#         mesh = pv.read(tempMeshPath + f"Trial{trial_id}_step{i}.vtu")
#         # add fish mesh to plotter
#         plotter.add_mesh(mesh, show_scalar_bar=False, name = 'mesh') # add the fish body
#         plotter.add_mesh(grid, clim=[-1, 1],show_scalar_bar=False, name = 'reference', opacity=0.5)
#         # add reference trajectory to plotter with thickness of 5 and large markers
#         opacities = np.linspace(1, 0.05, len(offsetPath))
#         plotter.add_mesh(pv.PolyData(offsetPath), color='orange', line_width=5, name = 'refPath', opacity=opacities, render_points_as_spheres=True, point_size=10)
#         # add output trajectory to plotter with thickness of 5 and large markers
#         plotter.add_mesh(pv.PolyData(offsetOutputCurve), color='blue', line_width=5, name = 'outputPath', opacity=opacities, render_points_as_spheres=True, point_size=10)
#         # Set the camera position - Isometric view
#         plotter.camera_position = 'yz'
#         plotter.camera.roll = 180
#         plotter.camera.azimuth = 40#90 #
#         plotter.camera.elevation = 50#0 #50
#         plotter.enable_parallel_projection()
#         # # Set the camera position - Top View Down
#         # plotter.camera_position = 'yz'
#         # plotter.camera.roll = 180
#         # plotter.camera.azimuth = 90 #
#         # plotter.camera.elevation = 90 #50
#         # plotter.enable_parallel_projection()


#         # write frame to gif
#         plotter.write_frame()
#     # Close the gif
#     plotter.close()

# %%
import matplotlib.pyplot as plt

opacities = np.linspace(1, 0.2, 20)
###### Generate mp4 of fish swimming with top and isometric views along with reference trajectory for specified trials
for trial_id in trial_ids:
    # create plotter objects
    plotter = pv.Plotter(shape=(2,1), border=False, row_weights = [0.4,1], window_size=[1000, 1000])
    # Open a mp4
    plotter.open_movie(outputPath + f"Trial{trial_id}_combinedView.mp4", framerate=100, quality=7)
    
    # Iterate through timesteps and add frames
    for i in range(timesteps):
        print(f"Trial {trial_id}, Timestep {i}")
        
        ### Make surface from desired reference trajectory
        # Load data from database
        conn = get_db_connection()
        data = fetch_trial_data_singleTimestep(conn, trial_id, 1, start_timestep=i, num_timesteps=1)
        conn.close()
        timestep, simulation_time, input_data, output_data, state_data, y_ref, x_hat = data[0]
        
        # Check shape of reference trajectory
        uncenteredRefTraj = y_ref + refOffsets
        # Turn reference trajectory from 40x1 to 20x2 array by taking every other point 
        x_refs = uncenteredRefTraj[::2]
        z_refs = uncenteredRefTraj[1::2]
        referenceCurve = np.column_stack((x_refs, np.zeros(np.size(x_refs)), z_refs))
        path = referenceCurve
        offsetPath = np.copy(path)
        offsetPath[:, 1] = offsetPath[:, 1] - 122
        
        #### Draw Surface for reference trajectory
        # Number of samples (in depth dir) and number of points along centerline 
        nsamples = 3
        ntraces = 20  
        # Define the Z spacing of your 2D section
        z_spacing = 60
        # Create structured points draping down from the path
        points = np.repeat(path, nsamples, axis=0)
        # repeat the Z locations across
        tp = np.arange(0, z_spacing * nsamples, z_spacing)
        # Offset the Z locations 
        tp = path[:, 1][:, None] - tp
        points[:, 1] = tp.ravel()
        # Make a StructuredGrid from the structured points
        grid = pv.StructuredGrid()
        grid.points = points
        grid.dimensions = nsamples, ntraces, 1
        # Add the data array - note the ordering
        grid["values"] = np.ones((nsamples, ntraces), dtype=np.float64).ravel(order="F")
        
        ### Plot actual centerline from output_data
        # Load data from database
        conn = get_db_connection()
        data = fetch_trial_data_singleTimestep(conn, trial_id, 1, start_timestep=i, num_timesteps=1)
        conn.close()
        timestep, simulation_time, input_data, output_data, state_data, y_ref, x_hat = data[0]
        
        # Check shape of output data
        uncenteredOutputTraj = output_data
        # Turn output trajectory from 40x1 to 20x2 array by taking every other point
        x_outs = uncenteredOutputTraj[::2]
        z_outs = uncenteredOutputTraj[1::2]
        outputCurve = np.column_stack((x_outs, np.zeros(np.size(x_outs)), z_outs))
        offsetOutputCurve = np.copy(outputCurve)
        offsetOutputCurve[:, 1] = offsetOutputCurve[:, 1] - 122
        
        # load mesh from .vtu file in tempMeshPath
        mesh = pv.read(tempMeshPath + f"Trial{trial_id}_step{i}.vtu")
        
        # Add meshes to top view window
        plotter.subplot(0, 0)
        plotter.add_mesh(mesh, show_scalar_bar=False, name='mesh')
        plotter.add_mesh(grid, clim=[-1, 1], show_scalar_bar=False, name='reference', opacity=0.5)
        plotter.add_mesh(pv.PolyData(offsetPath), color='orange', line_width=5, name='refPath', opacity=opacities, render_points_as_spheres=True, point_size=10)
        plotter.add_mesh(pv.PolyData(offsetOutputCurve), color='blue', line_width=5, name='outputPath', opacity=opacities, render_points_as_spheres=True, point_size=10)
        plotter.camera_position = 'yz'
        plotter.camera.roll = 180
        plotter.camera.azimuth = 90
        plotter.camera.elevation = 90
        plotter.enable_parallel_projection()
        # change bounds to be 0, 0, -200, 200, -200, 200
        plotter.camera_position = [
            (-558.609577998519, -2226.5518997921977, -13.31930130655202),
            (-558.609577998519, -19.333351135253906, -13.31930130655202),
            (0.0, -1.0, -2.220446049250313e-16)]
        plotter.camera.zoom(3)

        # Add meshes to isometric view window
        plotter.subplot(1, 0)
        plotter.add_mesh(mesh, show_scalar_bar=False, name='mesh')
        plotter.add_mesh(grid, clim=[-1, 1], show_scalar_bar=False, name='reference', opacity=0.5)
        plotter.add_mesh(pv.PolyData(offsetPath), color='orange', line_width=5, name='refPath', opacity=opacities, render_points_as_spheres=True, point_size=10)
        plotter.add_mesh(pv.PolyData(offsetOutputCurve), color='blue', line_width=5, name='outputPath', opacity=opacities, render_points_as_spheres=True, point_size=10)
        plotter.camera_position = 'yz'
        plotter.camera.roll = 180
        plotter.camera.azimuth = 40
        plotter.camera.elevation = 50
        plotter.enable_parallel_projection()
        plotter.camera_position = [
            (528.2333916563371, -1710.160855083042, 898.6502336784569),
            (-558.609577998519, -19.333351135253906, -13.31930130655202),
            (0.0, -1.0, -2.220446049250313e-16)]
        plotter.camera.zoom(1.25)        


        # plotter.show_bounds(all_edges=False)        
        # write frame to gif
        plotter.write_frame()
    # Close the gif
    plotter.close()
# Out:
# Trial 192, Timestep 0
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1000, 1000) to (1008, 1008) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Trial 192, Timestep 1
# Trial 192, Timestep 2
# Trial 192, Timestep 3
# Trial 192, Timestep 4
# Trial 192, Timestep 5
# Trial 192, Timestep 6
# Trial 192, Timestep 7
# Trial 192, Timestep 8
# Trial 192, Timestep 9
# Trial 192, Timestep 10
# Trial 192, Timestep 11
# Trial 192, Timestep 12
# Trial 192, Timestep 13
# Trial 192, Timestep 14
# Trial 192, Timestep 15
# Trial 192, Timestep 16
# Trial 192, Timestep 17
# Trial 192, Timestep 18
# Trial 192, Timestep 19
# Trial 192, Timestep 20
# Trial 192, Timestep 21
# Trial 192, Timestep 22
# Trial 192, Timestep 23
# Trial 192, Timestep 24
# Trial 192, Timestep 25
# Trial 192, Timestep 26
# Trial 192, Timestep 27
# Trial 192, Timestep 28
# Trial 192, Timestep 29
# Trial 192, Timestep 30
# Trial 192, Timestep 31
# Trial 192, Timestep 32
# Trial 192, Timestep 33
# Trial 192, Timestep 34
# Trial 192, Timestep 35
# Trial 192, Timestep 36
# Trial 192, Timestep 37
# Trial 192, Timestep 38
# Trial 192, Timestep 39
# Trial 192, Timestep 40
# Trial 192, Timestep 41
# Trial 192, Timestep 42
# Trial 192, Timestep 43
# Trial 192, Timestep 44
# Trial 192, Timestep 45
# Trial 192, Timestep 46
# Trial 192, Timestep 47
# Trial 192, Timestep 48
# Trial 192, Timestep 49
# Trial 192, Timestep 50
# Trial 192, Timestep 51
# Trial 192, Timestep 52
# Trial 192, Timestep 53
# Trial 192, Timestep 54
# Trial 192, Timestep 55
# Trial 192, Timestep 56
# Trial 192, Timestep 57
# Trial 192, Timestep 58
# Trial 192, Timestep 59
# Trial 192, Timestep 60
# Trial 192, Timestep 61
# Trial 192, Timestep 62
# Trial 192, Timestep 63
# Trial 192, Timestep 64
# Trial 192, Timestep 65
# Trial 192, Timestep 66
# Trial 192, Timestep 67
# Trial 192, Timestep 68
# Trial 192, Timestep 69
# Trial 192, Timestep 70
# Trial 192, Timestep 71
# Trial 192, Timestep 72
# Trial 192, Timestep 73
# Trial 192, Timestep 74
# Trial 192, Timestep 75
# Trial 192, Timestep 76
# Trial 192, Timestep 77
# Trial 192, Timestep 78
# Trial 192, Timestep 79
# Trial 192, Timestep 80
# Trial 192, Timestep 81
# Trial 192, Timestep 82
# Trial 192, Timestep 83
# Trial 192, Timestep 84
# Trial 192, Timestep 85
# Trial 192, Timestep 86
# Trial 192, Timestep 87
# Trial 192, Timestep 88
# Trial 192, Timestep 89
# Trial 192, Timestep 90
# Trial 192, Timestep 91
# Trial 192, Timestep 92
# Trial 192, Timestep 93
# Trial 192, Timestep 94
# Trial 192, Timestep 95
# Trial 192, Timestep 96
# Trial 192, Timestep 97
# Trial 192, Timestep 98
# Trial 192, Timestep 99
# Trial 192, Timestep 100
# Trial 192, Timestep 101
# Trial 192, Timestep 102
# Trial 192, Timestep 103
# Trial 192, Timestep 104
# Trial 192, Timestep 105
# Trial 192, Timestep 106
# Trial 192, Timestep 107
# Trial 192, Timestep 108
# Trial 192, Timestep 109
# Trial 192, Timestep 110
# Trial 192, Timestep 111
# Trial 192, Timestep 112
# Trial 192, Timestep 113
# Trial 192, Timestep 114
# Trial 192, Timestep 115
# Trial 192, Timestep 116
# Trial 192, Timestep 117
# Trial 192, Timestep 118
# Trial 192, Timestep 119
# Trial 192, Timestep 120
# Trial 192, Timestep 121
# Trial 192, Timestep 122
# Trial 192, Timestep 123
# Trial 192, Timestep 124
# Trial 192, Timestep 125
# Trial 192, Timestep 126
# Trial 192, Timestep 127
# Trial 192, Timestep 128
# Trial 192, Timestep 129
# Trial 192, Timestep 130
# Trial 192, Timestep 131
# Trial 192, Timestep 132
# Trial 192, Timestep 133
# Trial 192, Timestep 134
# Trial 192, Timestep 135
# Trial 192, Timestep 136
# Trial 192, Timestep 137
# Trial 192, Timestep 138
# Trial 192, Timestep 139
# Trial 192, Timestep 140
# Trial 192, Timestep 141
# Trial 192, Timestep 142
# Trial 192, Timestep 143
# Trial 192, Timestep 144
# Trial 192, Timestep 145
# Trial 192, Timestep 146
# Trial 192, Timestep 147
# Trial 192, Timestep 148
# Trial 192, Timestep 149
# Trial 192, Timestep 150
# Trial 192, Timestep 151
# Trial 192, Timestep 152
# Trial 192, Timestep 153
# Trial 192, Timestep 154
# Trial 192, Timestep 155
# Trial 192, Timestep 156
# Trial 192, Timestep 157
# Trial 192, Timestep 158
# Trial 192, Timestep 159
# Trial 192, Timestep 160
# Trial 192, Timestep 161
# Trial 192, Timestep 162
# Trial 192, Timestep 163
# Trial 192, Timestep 164
# Trial 192, Timestep 165
# Trial 192, Timestep 166
# Trial 192, Timestep 167
# Trial 192, Timestep 168
# Trial 192, Timestep 169
# Trial 192, Timestep 170
# Trial 192, Timestep 171
# Trial 192, Timestep 172
# Trial 192, Timestep 173
# Trial 192, Timestep 174
# Trial 192, Timestep 175
# Trial 192, Timestep 176
# Trial 192, Timestep 177
# Trial 192, Timestep 178
# Trial 192, Timestep 179
# Trial 192, Timestep 180
# Trial 192, Timestep 181
# Trial 192, Timestep 182
# Trial 192, Timestep 183
# Trial 192, Timestep 184
# Trial 192, Timestep 185
# Trial 192, Timestep 186
# Trial 192, Timestep 187
# Trial 192, Timestep 188
# Trial 192, Timestep 189
# Trial 192, Timestep 190
# Trial 192, Timestep 191
# Trial 192, Timestep 192
# Trial 192, Timestep 193
# Trial 192, Timestep 194
# Trial 192, Timestep 195
# Trial 192, Timestep 196
# Trial 192, Timestep 197
# Trial 192, Timestep 198
# Trial 192, Timestep 199
# Trial 192, Timestep 200
# Trial 192, Timestep 201
# Trial 192, Timestep 202
# Trial 192, Timestep 203
# Trial 192, Timestep 204
# Trial 192, Timestep 205
# Trial 192, Timestep 206
# Trial 192, Timestep 207
# Trial 192, Timestep 208
# Trial 192, Timestep 209
# Trial 192, Timestep 210
# Trial 192, Timestep 211
# Trial 192, Timestep 212
# Trial 192, Timestep 213
# Trial 192, Timestep 214
# Trial 192, Timestep 215
# Trial 192, Timestep 216
# Trial 192, Timestep 217
# Trial 192, Timestep 218
# Trial 192, Timestep 219
# Trial 192, Timestep 220
# Trial 192, Timestep 221
# Trial 192, Timestep 222
# Trial 192, Timestep 223
# Trial 192, Timestep 224
# Trial 192, Timestep 225
# Trial 192, Timestep 226
# Trial 192, Timestep 227
# Trial 192, Timestep 228
# Trial 192, Timestep 229
# Trial 192, Timestep 230
# Trial 192, Timestep 231
# Trial 192, Timestep 232
# Trial 192, Timestep 233
# Trial 192, Timestep 234
# Trial 192, Timestep 235
# Trial 192, Timestep 236
# Trial 192, Timestep 237
# Trial 192, Timestep 238
# Trial 192, Timestep 239
# Trial 192, Timestep 240
# Trial 192, Timestep 241
# Trial 192, Timestep 242
# Trial 192, Timestep 243
# Trial 192, Timestep 244
# Trial 192, Timestep 245
# Trial 192, Timestep 246
# Trial 192, Timestep 247
# Trial 192, Timestep 248
# Trial 192, Timestep 249
# Trial 192, Timestep 250
# Trial 192, Timestep 251
# Trial 192, Timestep 252
# Trial 192, Timestep 253
# Trial 192, Timestep 254
# Trial 192, Timestep 255
# Trial 192, Timestep 256
# Trial 192, Timestep 257
# Trial 192, Timestep 258
# Trial 192, Timestep 259
# Trial 192, Timestep 260
# Trial 192, Timestep 261
# Trial 192, Timestep 262
# Trial 192, Timestep 263
# Trial 192, Timestep 264
# Trial 192, Timestep 265
# Trial 192, Timestep 266
# Trial 192, Timestep 267
# Trial 192, Timestep 268
# Trial 192, Timestep 269
# Trial 192, Timestep 270
# Trial 192, Timestep 271
# Trial 192, Timestep 272
# Trial 192, Timestep 273
# Trial 192, Timestep 274
# Trial 192, Timestep 275
# Trial 192, Timestep 276
# Trial 192, Timestep 277
# Trial 192, Timestep 278
# Trial 192, Timestep 279
# Trial 192, Timestep 280
# Trial 192, Timestep 281
# Trial 192, Timestep 282
# Trial 192, Timestep 283
# Trial 192, Timestep 284
# Trial 192, Timestep 285
# Trial 192, Timestep 286
# Trial 192, Timestep 287
# Trial 192, Timestep 288
# Trial 192, Timestep 289
# Trial 192, Timestep 290
# Trial 192, Timestep 291
# Trial 192, Timestep 292
# Trial 192, Timestep 293
# Trial 192, Timestep 294
# Trial 192, Timestep 295
# Trial 192, Timestep 296
# Trial 192, Timestep 297
# Trial 192, Timestep 298
# Trial 192, Timestep 299
# Trial 192, Timestep 300
# Trial 192, Timestep 301
# Trial 192, Timestep 302
# Trial 192, Timestep 303
# Trial 192, Timestep 304
# Trial 192, Timestep 305
# Trial 192, Timestep 306
# Trial 192, Timestep 307
# Trial 192, Timestep 308
# Trial 192, Timestep 309
# Trial 192, Timestep 310
# Trial 192, Timestep 311
# Trial 192, Timestep 312
# Trial 192, Timestep 313
# Trial 192, Timestep 314
# Trial 192, Timestep 315
# Trial 192, Timestep 316
# Trial 192, Timestep 317
# Trial 192, Timestep 318
# Trial 192, Timestep 319
# Trial 192, Timestep 320
# Trial 192, Timestep 321
# Trial 192, Timestep 322
# Trial 192, Timestep 323
# Trial 192, Timestep 324
# Trial 192, Timestep 325
# Trial 192, Timestep 326
# Trial 192, Timestep 327
# Trial 192, Timestep 328
# Trial 192, Timestep 329
# Trial 192, Timestep 330
# Trial 192, Timestep 331
# Trial 192, Timestep 332
# Trial 192, Timestep 333
# Trial 192, Timestep 334
# Trial 192, Timestep 335
# Trial 192, Timestep 336
# Trial 192, Timestep 337
# Trial 192, Timestep 338
# Trial 192, Timestep 339
# Trial 192, Timestep 340
# Trial 192, Timestep 341
# Trial 192, Timestep 342
# Trial 192, Timestep 343
# Trial 192, Timestep 344
# Trial 192, Timestep 345
# Trial 192, Timestep 346
# Trial 192, Timestep 347
# Trial 192, Timestep 348
# Trial 192, Timestep 349
# Trial 192, Timestep 350
# Trial 192, Timestep 351
# Trial 192, Timestep 352
# Trial 192, Timestep 353
# Trial 192, Timestep 354
# Trial 192, Timestep 355
# Trial 192, Timestep 356
# Trial 192, Timestep 357
# Trial 192, Timestep 358
# Trial 192, Timestep 359
# Trial 192, Timestep 360
# Trial 192, Timestep 361
# Trial 192, Timestep 362
# Trial 192, Timestep 363
# Trial 192, Timestep 364
# Trial 192, Timestep 365
# Trial 192, Timestep 366
# Trial 192, Timestep 367
# Trial 192, Timestep 368
# Trial 192, Timestep 369
# Trial 192, Timestep 370
# Trial 192, Timestep 371
# Trial 192, Timestep 372
# Trial 192, Timestep 373
# Trial 192, Timestep 374
# Trial 192, Timestep 375
# Trial 192, Timestep 376
# Trial 192, Timestep 377
# Trial 192, Timestep 378
# Trial 192, Timestep 379
# Trial 192, Timestep 380
# Trial 192, Timestep 381
# Trial 192, Timestep 382
# Trial 192, Timestep 383
# Trial 192, Timestep 384
# Trial 192, Timestep 385
# Trial 192, Timestep 386
# Trial 192, Timestep 387
# Trial 192, Timestep 388
# Trial 192, Timestep 389
# Trial 192, Timestep 390
# Trial 192, Timestep 391
# Trial 192, Timestep 392
# Trial 192, Timestep 393
# Trial 192, Timestep 394
# Trial 192, Timestep 395
# Trial 192, Timestep 396
# Trial 192, Timestep 397
# Trial 192, Timestep 398
# Trial 192, Timestep 399
# Trial 192, Timestep 400
# Trial 192, Timestep 401
# Trial 192, Timestep 402
# Trial 192, Timestep 403
# Trial 192, Timestep 404
# Trial 192, Timestep 405
# Trial 192, Timestep 406
# Trial 192, Timestep 407
# Trial 192, Timestep 408
# Trial 192, Timestep 409
# Trial 192, Timestep 410
# Trial 192, Timestep 411
# Trial 192, Timestep 412
# Trial 192, Timestep 413
# Trial 192, Timestep 414
# Trial 192, Timestep 415
# Trial 192, Timestep 416
# Trial 192, Timestep 417
# Trial 192, Timestep 418
# Trial 192, Timestep 419
# Trial 192, Timestep 420
# Trial 192, Timestep 421
# Trial 192, Timestep 422
# Trial 192, Timestep 423
# Trial 192, Timestep 424
# Trial 192, Timestep 425
# Trial 192, Timestep 426
# Trial 192, Timestep 427
# Trial 192, Timestep 428
# Trial 192, Timestep 429
# Trial 192, Timestep 430
# Trial 192, Timestep 431
# Trial 192, Timestep 432
# Trial 192, Timestep 433
# Trial 192, Timestep 434
# Trial 192, Timestep 435
# Trial 192, Timestep 436
# Trial 192, Timestep 437
# Trial 192, Timestep 438
# Trial 192, Timestep 439
# Trial 192, Timestep 440
# Trial 192, Timestep 441
# Trial 192, Timestep 442
# Trial 192, Timestep 443
# Trial 192, Timestep 444
# Trial 192, Timestep 445
# Trial 192, Timestep 446
# Trial 192, Timestep 447
# Trial 192, Timestep 448
# Trial 192, Timestep 449
# Trial 192, Timestep 450
# Trial 192, Timestep 451
# Trial 192, Timestep 452
# Trial 192, Timestep 453
# Trial 192, Timestep 454
# Trial 192, Timestep 455
# Trial 192, Timestep 456
# Trial 192, Timestep 457
# Trial 192, Timestep 458
# Trial 192, Timestep 459
# Trial 192, Timestep 460
# Trial 192, Timestep 461
# Trial 192, Timestep 462
# Trial 192, Timestep 463
# Trial 192, Timestep 464
# Trial 192, Timestep 465
# Trial 192, Timestep 466
# Trial 192, Timestep 467
# Trial 192, Timestep 468
# Trial 192, Timestep 469
# Trial 192, Timestep 470
# Trial 192, Timestep 471
# Trial 192, Timestep 472
# Trial 192, Timestep 473
# Trial 192, Timestep 474
# Trial 192, Timestep 475
# Trial 192, Timestep 476
# Trial 192, Timestep 477
# Trial 192, Timestep 478
# Trial 192, Timestep 479
# Trial 192, Timestep 480
# Trial 192, Timestep 481
# Trial 192, Timestep 482
# Trial 192, Timestep 483
# Trial 192, Timestep 484
# Trial 192, Timestep 485
# Trial 192, Timestep 486
# Trial 192, Timestep 487
# Trial 192, Timestep 488
# Trial 192, Timestep 489
# Trial 192, Timestep 490
# Trial 192, Timestep 491
# Trial 192, Timestep 492
# Trial 192, Timestep 493
# Trial 192, Timestep 494
# Trial 192, Timestep 495
# Trial 192, Timestep 496
# Trial 192, Timestep 497
# Trial 192, Timestep 498
# Trial 192, Timestep 499
