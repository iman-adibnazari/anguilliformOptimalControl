# %%
import pyvista as pv
import meshio
import numpy as np
import psycopg2
import hdf5storage
import h5py
import pickle
import logging
from sys import getsizeof
from dotenv import dotenv_values

pv.global_theme.transparent_background = True


config = dotenv_values("../.env")
# Filepaths for script
initMeshPath = config["currentDirectory"] +"meshes/fullAssemblyContiguous/fullFishContiguous.msh"
tempMeshPath = config["backupDirectory"] + "data/visualizations/holdpls/"
outputPath = config["currentDirectory"] + "data/visualizations/controlExperiments/"

# %%
# Helper functions for working with database
def get_db_connection():
    conn = psycopg2.connect(
        dbname='simDB',
        user='user',
        password='password',
        host='localhost',
        port='5432'
    )
    return conn

def fetch_trial_data_singleTimestep(conn, trial_id, n=1, start_timestep=0, num_timesteps=500):
    try:
        cur = conn.cursor()
        
        # Fetch data for the given trial_id starting from start_timestep
        query = '''
        SELECT timestep, simulation_time, input_data, output_data, state_data, y_ref, x_hat
        FROM simulation_data
        WHERE trial_id = %s AND timestep >= %s AND timestep < %s
        ORDER BY timestep ASC;
        '''
        cur.execute(query, (trial_id, start_timestep, start_timestep + 1))
        rows = cur.fetchall()
        
        # Deserialize data
        data = []
        for row in rows:
            timestep, simulation_time, input_data_bin, output_data_bin, state_data_bin, y_ref_bin, x_hat_bin = row
            input_data = np.array(pickle.loads(input_data_bin))
            output_data = np.array(pickle.loads(output_data_bin))
            state_data = np.array(pickle.loads(state_data_bin))
            y_ref = np.array(pickle.loads(y_ref_bin))
            x_hat = np.array(pickle.loads(x_hat_bin))
            data.append((timestep, simulation_time, input_data, output_data,state_data, y_ref, x_hat))
        
        cur.close()
        return data
    except Exception as e:
        print(f"Error fetching data for trial_id {trial_id}: {e}")
        return None

# %%
# Trial Parameters
trial_ids = [162, 163]
timesteps = 1500

# %%
### Get offsets for reference trajectory
# Load data from database
conn = get_db_connection()
data = fetch_trial_data_singleTimestep(conn, trial_ids[0], 1, start_timestep=0, num_timesteps=1)
conn.close()
timestep, simulation_time, input_data, output_data, state_data, y_ref, x_hat = data[0]
# Get the reference trajectory
refOffsets = np.copy(output_data)

# %%
# ###### Generate mp4 of fish swimming in isometric view along with reference trajectory for specified trials
# for trial_id in trial_ids:
#     # create plotter object
#     plotter = pv.Plotter()
#     # Open a mp4
#     plotter.open_movie(outputPath + f"Trial{trial_id}_isoView.mp4", framerate = 100, quality=7)
#     # Iterate through timesteps and add frames
#     for i in range(timesteps):
#         print(f"Trial {trial_id}, Timestep {i}")
#         ### Make surface from desired reference trajectory
#         # Load data from database
#         conn = get_db_connection()
#         data = fetch_trial_data_singleTimestep(conn, trial_id, 1, start_timestep=i, num_timesteps=1)
#         conn.close()
#         timestep, simulation_time, input_data, output_data, state_data, y_ref, x_hat = data[0]
#         # Check shape of reference trajectory
#         uncenteredRefTraj=y_ref + refOffsets
#         # Turn reference trajectory from 40x1 to 20x2 array by taking every other point 
#         x_refs = uncenteredRefTraj[::2]
#         z_refs = uncenteredRefTraj[1::2]
#         referenceCurve = np.column_stack((x_refs, np.zeros(np.size(x_refs)), z_refs))
#         # print(np.shape(referenceCurve))
#         path = referenceCurve
#         offsetPath = np.copy(path)
#         offsetPath[:, 1] = offsetPath[:, 1] - 102
#         #### Draw Surface for reference trajectory
#         # Number of samples (in depth dir) and number of points along centerline 
#         nsamples = 3
#         ntraces = 20  
#         # Define the Z spacing of your 2D section
#         z_spacing = 50
#         # Create structured points draping down from the path
#         points = np.repeat(path, nsamples, axis=0)
#         # repeat the Z locations across
#         tp = np.arange(0, z_spacing * nsamples, z_spacing)
#         # Offset the Z locations 
#         tp = path[:, 1][:, None] - tp
#         points[:, 1] = tp.ravel()
#         #Make a StructuredGrid from the structured points
#         grid = pv.StructuredGrid()
#         grid.points = points
#         grid.dimensions = nsamples, ntraces, 1
#         # Add the data array - note the ordering
#         grid["values"] = np.ones((nsamples, ntraces), dtype=np.float64).ravel(order="F")

#         ### Plot actual centerline from output_data
#         # Load data from database
#         conn = get_db_connection()
#         data = fetch_trial_data_singleTimestep(conn, trial_id, 1, start_timestep=i, num_timesteps=1)
#         conn.close()
#         timestep, simulation_time, input_data, output_data, state_data, y_ref, x_hat = data[0]
#         # Check shape of output data
#         uncenteredOutputTraj=output_data
#         # Turn output trajectory from 40x1 to 20x2 array by taking every other point
#         x_outs = uncenteredOutputTraj[::2]
#         z_outs = uncenteredOutputTraj[1::2]
#         outputCurve = np.column_stack((x_outs, np.zeros(np.size(x_outs)), z_outs))
#         # print(np.shape(outputCurve))
#         offsetOutputCurve = np.copy(outputCurve)
#         offsetOutputCurve[:, 1] = offsetOutputCurve[:, 1] - 102


        

#         # load mesh from .vtu file in tempMeshPath
#         mesh = pv.read(tempMeshPath + f"Trial{trial_id}_step{i}.vtu")
#         # add fish mesh to plotter
#         plotter.add_mesh(mesh, show_scalar_bar=False, name = 'mesh') # add the fish body
#         plotter.add_mesh(grid, clim=[-1, 1],show_scalar_bar=False, name = 'reference', opacity=0.5)
#         # add reference trajectory to plotter with thickness of 5 and large markers
#         opacities = np.linspace(1, 0.05, len(offsetPath))
#         plotter.add_mesh(pv.PolyData(offsetPath), color='orange', line_width=5, name = 'refPath', opacity=opacities, render_points_as_spheres=True, point_size=10)
#         # add output trajectory to plotter with thickness of 5 and large markers
#         plotter.add_mesh(pv.PolyData(offsetOutputCurve), color='blue', line_width=5, name = 'outputPath', opacity=opacities, render_points_as_spheres=True, point_size=10)
#         # Set the camera position - Isometric view
#         plotter.camera_position = 'yz'
#         plotter.camera.roll = 180
#         plotter.camera.azimuth = 40#90 #
#         plotter.camera.elevation = 50#0 #50
#         plotter.enable_parallel_projection()
#         # # Set the camera position - Top View Down
#         # plotter.camera_position = 'yz'
#         # plotter.camera.roll = 180
#         # plotter.camera.azimuth = 90 #
#         # plotter.camera.elevation = 90 #50
#         # plotter.enable_parallel_projection()


#         # write frame to gif
#         plotter.write_frame()
#     # Close the gif
#     plotter.close()

# %%
import matplotlib.pyplot as plt

opacities = np.linspace(1, 0.2, 20)
###### Generate mp4 of fish swimming with top and isometric views along with reference trajectory for specified trials
for trial_id in trial_ids:
    # create plotter objects
    plotter = pv.Plotter(shape=(2,1), border=False, row_weights = [0.4,1], window_size=[1000, 1000])
    # Open a mp4
    plotter.open_movie(outputPath + f"Trial{trial_id}_combinedView.mp4", framerate=100, quality=7)
    
    # Iterate through timesteps and add frames
    for i in range(timesteps):
        print(f"Trial {trial_id}, Timestep {i}")
        
        ### Make surface from desired reference trajectory
        # Load data from database
        conn = get_db_connection()
        data = fetch_trial_data_singleTimestep(conn, trial_id, 1, start_timestep=i, num_timesteps=1)
        conn.close()
        timestep, simulation_time, input_data, output_data, state_data, y_ref, x_hat = data[0]
        
        # Check shape of reference trajectory
        uncenteredRefTraj = y_ref + refOffsets
        # Turn reference trajectory from 40x1 to 20x2 array by taking every other point 
        x_refs = uncenteredRefTraj[::2]
        z_refs = uncenteredRefTraj[1::2]
        referenceCurve = np.column_stack((x_refs, np.zeros(np.size(x_refs)), z_refs))
        path = referenceCurve
        offsetPath = np.copy(path)
        offsetPath[:, 1] = offsetPath[:, 1] - 122
        
        #### Draw Surface for reference trajectory
        # Number of samples (in depth dir) and number of points along centerline 
        nsamples = 3
        ntraces = 20  
        # Define the Z spacing of your 2D section
        z_spacing = 60
        # Create structured points draping down from the path
        points = np.repeat(path, nsamples, axis=0)
        # repeat the Z locations across
        tp = np.arange(0, z_spacing * nsamples, z_spacing)
        # Offset the Z locations 
        tp = path[:, 1][:, None] - tp
        points[:, 1] = tp.ravel()
        # Make a StructuredGrid from the structured points
        grid = pv.StructuredGrid()
        grid.points = points
        grid.dimensions = nsamples, ntraces, 1
        # Add the data array - note the ordering
        grid["values"] = np.ones((nsamples, ntraces), dtype=np.float64).ravel(order="F")
        
        ### Plot actual centerline from output_data
        # Load data from database
        conn = get_db_connection()
        data = fetch_trial_data_singleTimestep(conn, trial_id, 1, start_timestep=i, num_timesteps=1)
        conn.close()
        timestep, simulation_time, input_data, output_data, state_data, y_ref, x_hat = data[0]
        
        # Check shape of output data
        uncenteredOutputTraj = output_data
        # Turn output trajectory from 40x1 to 20x2 array by taking every other point
        x_outs = uncenteredOutputTraj[::2]
        z_outs = uncenteredOutputTraj[1::2]
        outputCurve = np.column_stack((x_outs, np.zeros(np.size(x_outs)), z_outs))
        offsetOutputCurve = np.copy(outputCurve)
        offsetOutputCurve[:, 1] = offsetOutputCurve[:, 1] - 122
        
        # load mesh from .vtu file in tempMeshPath
        mesh = pv.read(tempMeshPath + f"Trial{trial_id}_step{i}.vtu")
        
        # Add meshes to top view window
        plotter.subplot(0, 0)
        plotter.add_mesh(mesh, show_scalar_bar=False, name='mesh')
        plotter.add_mesh(grid, clim=[-1, 1], show_scalar_bar=False, name='reference', opacity=0.5)
        plotter.add_mesh(pv.PolyData(offsetPath), color='orange', line_width=5, name='refPath', opacity=opacities, render_points_as_spheres=True, point_size=10)
        plotter.add_mesh(pv.PolyData(offsetOutputCurve), color='blue', line_width=5, name='outputPath', opacity=opacities, render_points_as_spheres=True, point_size=10)
        plotter.camera_position = 'yz'
        plotter.camera.roll = 180
        plotter.camera.azimuth = 90
        plotter.camera.elevation = 90
        plotter.enable_parallel_projection()
        # change bounds to be 0, 0, -200, 200, -200, 200
        plotter.camera_position = [
            (-558.609577998519, -2226.5518997921977, -13.31930130655202),
            (-558.609577998519, -19.333351135253906, -13.31930130655202),
            (0.0, -1.0, -2.220446049250313e-16)]
        plotter.camera.zoom(3)

        # Add meshes to isometric view window
        plotter.subplot(1, 0)
        plotter.add_mesh(mesh, show_scalar_bar=False, name='mesh')
        plotter.add_mesh(grid, clim=[-1, 1], show_scalar_bar=False, name='reference', opacity=0.5)
        plotter.add_mesh(pv.PolyData(offsetPath), color='orange', line_width=5, name='refPath', opacity=opacities, render_points_as_spheres=True, point_size=10)
        plotter.add_mesh(pv.PolyData(offsetOutputCurve), color='blue', line_width=5, name='outputPath', opacity=opacities, render_points_as_spheres=True, point_size=10)
        plotter.camera_position = 'yz'
        plotter.camera.roll = 180
        plotter.camera.azimuth = 40
        plotter.camera.elevation = 50
        plotter.enable_parallel_projection()
        plotter.camera_position = [
            (528.2333916563371, -1710.160855083042, 898.6502336784569),
            (-558.609577998519, -19.333351135253906, -13.31930130655202),
            (0.0, -1.0, -2.220446049250313e-16)]
        plotter.camera.zoom(1.25)        


        # plotter.show_bounds(all_edges=False)        
        # write frame to gif
        plotter.write_frame()
    # Close the gif
    plotter.close()
# Out:
# Trial 162, Timestep 0
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1000, 1000) to (1008, 1008) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Trial 162, Timestep 1
# Trial 162, Timestep 2
# Trial 162, Timestep 3
# Trial 162, Timestep 4
# Trial 162, Timestep 5
# Trial 162, Timestep 6
# Trial 162, Timestep 7
# Trial 162, Timestep 8
# Trial 162, Timestep 9
# Trial 162, Timestep 10
# Trial 162, Timestep 11
# Trial 162, Timestep 12
# Trial 162, Timestep 13
# Trial 162, Timestep 14
# Trial 162, Timestep 15
# Trial 162, Timestep 16
# Trial 162, Timestep 17
# Trial 162, Timestep 18
# Trial 162, Timestep 19
# Trial 162, Timestep 20
# Trial 162, Timestep 21
# Trial 162, Timestep 22
# Trial 162, Timestep 23
# Trial 162, Timestep 24
# Trial 162, Timestep 25
# Trial 162, Timestep 26
# Trial 162, Timestep 27
# Trial 162, Timestep 28
# Trial 162, Timestep 29
# Trial 162, Timestep 30
# Trial 162, Timestep 31
# Trial 162, Timestep 32
# Trial 162, Timestep 33
# Trial 162, Timestep 34
# Trial 162, Timestep 35
# Trial 162, Timestep 36
# Trial 162, Timestep 37
# Trial 162, Timestep 38
# Trial 162, Timestep 39
# Trial 162, Timestep 40
# Trial 162, Timestep 41
# Trial 162, Timestep 42
# Trial 162, Timestep 43
# Trial 162, Timestep 44
# Trial 162, Timestep 45
# Trial 162, Timestep 46
# Trial 162, Timestep 47
# Trial 162, Timestep 48
# Trial 162, Timestep 49
# Trial 162, Timestep 50
# Trial 162, Timestep 51
# Trial 162, Timestep 52
# Trial 162, Timestep 53
# Trial 162, Timestep 54
# Trial 162, Timestep 55
# Trial 162, Timestep 56
# Trial 162, Timestep 1033
# Trial 162, Timestep 1034
# Trial 162, Timestep 1035
# Trial 162, Timestep 1036
# Trial 162, Timestep 1037
# Trial 162, Timestep 1038
# Trial 162, Timestep 1039
# Trial 162, Timestep 1040
# Trial 162, Timestep 1041
# Trial 162, Timestep 1042
# Trial 162, Timestep 1043
# Trial 162, Timestep 1044
# Trial 162, Timestep 1045
# Trial 162, Timestep 1046
# Trial 162, Timestep 1047
# Trial 162, Timestep 1048
# Trial 162, Timestep 1049
# Trial 162, Timestep 1050
# Trial 162, Timestep 1051
# Trial 162, Timestep 1052
# Trial 162, Timestep 1053
# Trial 162, Timestep 1054
# Trial 162, Timestep 1055
# Trial 162, Timestep 1056
# Trial 162, Timestep 1057
# Trial 162, Timestep 1058
# Trial 162, Timestep 1059
# Trial 162, Timestep 1060
# Trial 162, Timestep 1061
# Trial 162, Timestep 1062
# Trial 162, Timestep 1063
# Trial 162, Timestep 1064
# Trial 162, Timestep 1065
# Trial 162, Timestep 1066
# Trial 162, Timestep 1067
# Trial 162, Timestep 1068
# Trial 162, Timestep 1069
# Trial 162, Timestep 1070
# Trial 162, Timestep 1071
# Trial 162, Timestep 1072
# Trial 162, Timestep 1073
# Trial 162, Timestep 1074
# Trial 162, Timestep 1075
# Trial 162, Timestep 1076
# Trial 162, Timestep 1077
# Trial 162, Timestep 1078
# Trial 162, Timestep 1079
# Trial 162, Timestep 1080
# Trial 162, Timestep 1081
# Trial 162, Timestep 1082
# Trial 162, Timestep 1083
# Trial 162, Timestep 1084
# Trial 162, Timestep 1085
# Trial 162, Timestep 1086
# Trial 162, Timestep 1087
# Trial 162, Timestep 1088
# Trial 162, Timestep 1089
# Trial 162, Timestep 1090
# Trial 162, Timestep 1091
# Trial 162, Timestep 1092
# Trial 162, Timestep 1093
# Trial 162, Timestep 1094
# Trial 162, Timestep 1095
# Trial 162, Timestep 1096
# Trial 162, Timestep 1097
# Trial 162, Timestep 1098
# Trial 162, Timestep 1099
# Trial 162, Timestep 1100
# Trial 162, Timestep 1101
# Trial 162, Timestep 1102
# Trial 162, Timestep 1103
# Trial 162, Timestep 1104
# Trial 162, Timestep 1105
# Trial 162, Timestep 1106
# Trial 162, Timestep 1107
# Trial 162, Timestep 1108
# Trial 162, Timestep 1109
# Trial 162, Timestep 1110
# Trial 162, Timestep 1111
# Trial 162, Timestep 1112
# Trial 162, Timestep 1113
# Trial 162, Timestep 1114
# Trial 162, Timestep 1115
# Trial 162, Timestep 1116
# Trial 162, Timestep 1117
# Trial 162, Timestep 1118
# Trial 162, Timestep 1119
# Trial 162, Timestep 1120
# Trial 162, Timestep 1121
# Trial 162, Timestep 1122
# Trial 162, Timestep 1123
# Trial 162, Timestep 1124
# Trial 162, Timestep 1125
# Trial 162, Timestep 1126
# Trial 162, Timestep 1127
# Trial 162, Timestep 1128
# Trial 162, Timestep 1129
# Trial 162, Timestep 1130
# Trial 162, Timestep 1131
# Trial 162, Timestep 1132
# Trial 162, Timestep 1133
# Trial 162, Timestep 1134
# Trial 162, Timestep 1135
# Trial 162, Timestep 1136
# Trial 162, Timestep 1137
# Trial 162, Timestep 1138
# Trial 162, Timestep 1139
# Trial 162, Timestep 1140
# Trial 162, Timestep 1141
# Trial 162, Timestep 1142
# Trial 162, Timestep 1143
# Trial 162, Timestep 1144
# Trial 162, Timestep 1145
# Trial 162, Timestep 1146
# Trial 162, Timestep 1147
# Trial 162, Timestep 1148
# Trial 162, Timestep 1149
# Trial 162, Timestep 1150
# Trial 162, Timestep 1151
# Trial 162, Timestep 1152
# Trial 162, Timestep 1153
# Trial 162, Timestep 1154
# Trial 162, Timestep 1155
# Trial 162, Timestep 1156
# Trial 162, Timestep 1157
# Trial 162, Timestep 1158
# Trial 162, Timestep 1159
# Trial 162, Timestep 1160
# Trial 162, Timestep 1161
# Trial 162, Timestep 1162
# Trial 162, Timestep 1163
# Trial 162, Timestep 1164
# Trial 162, Timestep 1165
# Trial 162, Timestep 1166
# Trial 162, Timestep 1167
# Trial 162, Timestep 1168
# Trial 162, Timestep 1169
# Trial 162, Timestep 1170
# Trial 162, Timestep 1171
# Trial 162, Timestep 1172
# Trial 162, Timestep 1173
# Trial 162, Timestep 1174
# Trial 162, Timestep 1175
# Trial 162, Timestep 1176
# Trial 162, Timestep 1177
# Trial 162, Timestep 1178
# Trial 162, Timestep 1179
# Trial 162, Timestep 1180
# Trial 162, Timestep 1181
# Trial 162, Timestep 1182
# Trial 162, Timestep 1183
# Trial 162, Timestep 1184
# Trial 162, Timestep 1185
# Trial 162, Timestep 1186
# Trial 162, Timestep 1187
# Trial 162, Timestep 1188
# Trial 162, Timestep 1189
# Trial 162, Timestep 1190
# Trial 162, Timestep 1191
# Trial 162, Timestep 1192
# Trial 162, Timestep 1193
# Trial 162, Timestep 1194
# Trial 162, Timestep 1195
# Trial 162, Timestep 1196
# Trial 162, Timestep 1197
# Trial 162, Timestep 1198
# Trial 162, Timestep 1199
# Trial 162, Timestep 1200
# Trial 162, Timestep 1201
# Trial 162, Timestep 1202
# Trial 162, Timestep 1203
# Trial 162, Timestep 1204
# Trial 162, Timestep 1205
# Trial 162, Timestep 1206
# Trial 162, Timestep 1207
# Trial 162, Timestep 1208
# Trial 162, Timestep 1209
# Trial 162, Timestep 1210
# Trial 162, Timestep 1211
# Trial 162, Timestep 1212
# Trial 162, Timestep 1213
# Trial 162, Timestep 1214
# Trial 162, Timestep 1215
# Trial 162, Timestep 1216
# Trial 162, Timestep 1217
# Trial 162, Timestep 1218
# Trial 162, Timestep 1219
# Trial 162, Timestep 1220
# Trial 162, Timestep 1221
# Trial 162, Timestep 1222
# Trial 162, Timestep 1223
# Trial 162, Timestep 1224
# Trial 162, Timestep 1225
# Trial 162, Timestep 1226
# Trial 162, Timestep 1227
# Trial 162, Timestep 1228
# Trial 162, Timestep 1229
# Trial 162, Timestep 1230
# Trial 162, Timestep 1231
# Trial 162, Timestep 1232
# Trial 162, Timestep 1233
# Trial 162, Timestep 1234
# Trial 162, Timestep 1235
# Trial 162, Timestep 1236
# Trial 162, Timestep 1237
# Trial 162, Timestep 1238
# Trial 162, Timestep 1239
# Trial 162, Timestep 1240
# Trial 162, Timestep 1241
# Trial 162, Timestep 1242
# Trial 162, Timestep 1243
# Trial 162, Timestep 1244
# Trial 162, Timestep 1245
# Trial 162, Timestep 1246
# Trial 162, Timestep 1247
# Trial 162, Timestep 1248
# Trial 162, Timestep 1249
# Trial 162, Timestep 1250
# Trial 162, Timestep 1251
# Trial 162, Timestep 1252
# Trial 162, Timestep 1253
# Trial 162, Timestep 1254
# Trial 162, Timestep 1255
# Trial 162, Timestep 1256
# Trial 162, Timestep 1257
# Trial 162, Timestep 1258
# Trial 162, Timestep 1259
# Trial 162, Timestep 1260
# Trial 162, Timestep 1261
# Trial 162, Timestep 1262
# Trial 162, Timestep 1263
# Trial 162, Timestep 1264
# Trial 162, Timestep 1265
# Trial 162, Timestep 1266
# Trial 162, Timestep 1267
# Trial 162, Timestep 1268
# Trial 162, Timestep 1269
# Trial 162, Timestep 1270
# Trial 162, Timestep 1271
# Trial 162, Timestep 1272
# Trial 162, Timestep 1273
# Trial 162, Timestep 1274
# Trial 162, Timestep 1275
# Trial 162, Timestep 1276
# Trial 162, Timestep 1277
# Trial 162, Timestep 1278
# Trial 162, Timestep 1279
# Trial 162, Timestep 1280
# Trial 162, Timestep 1281
# Trial 162, Timestep 1282
# Trial 162, Timestep 1283
# Trial 162, Timestep 1284
# Trial 162, Timestep 1285
# Trial 162, Timestep 1286
# Trial 162, Timestep 1287
# Trial 162, Timestep 1288
# Trial 162, Timestep 1289
# Trial 162, Timestep 1290
# Trial 162, Timestep 1291
# Trial 162, Timestep 1292
# Trial 162, Timestep 1293
# Trial 162, Timestep 1294
# Trial 162, Timestep 1295
# Trial 162, Timestep 1296
# Trial 162, Timestep 1297
# Trial 162, Timestep 1298
# Trial 162, Timestep 1299
# Trial 162, Timestep 1300
# Trial 162, Timestep 1301
# Trial 162, Timestep 1302
# Trial 162, Timestep 1303
# Trial 162, Timestep 1304
# Trial 162, Timestep 1305
# Trial 162, Timestep 1306
# Trial 162, Timestep 1307
# Trial 162, Timestep 1308
# Trial 162, Timestep 1309
# Trial 162, Timestep 1310
# Trial 162, Timestep 1311
# Trial 162, Timestep 1312
# Trial 162, Timestep 1313
# Trial 162, Timestep 1314
# Trial 162, Timestep 1315
# Trial 162, Timestep 1316
# Trial 162, Timestep 1317
# Trial 162, Timestep 1318
# Trial 162, Timestep 1319
# Trial 162, Timestep 1320
# Trial 162, Timestep 1321
# Trial 162, Timestep 1322
# Trial 162, Timestep 1323
# Trial 162, Timestep 1324
# Trial 162, Timestep 1325
# Trial 162, Timestep 1326
# Trial 162, Timestep 1327
# Trial 162, Timestep 1328
# Trial 162, Timestep 1329
# Trial 162, Timestep 1330
# Trial 162, Timestep 1331
# Trial 162, Timestep 1332
# Trial 162, Timestep 1333
# Trial 162, Timestep 1334
# Trial 162, Timestep 1335
# Trial 162, Timestep 1336
# Trial 162, Timestep 1337
# Trial 162, Timestep 1338
# Trial 162, Timestep 1339
# Trial 162, Timestep 1340
# Trial 162, Timestep 1341
# Trial 162, Timestep 1342
# Trial 162, Timestep 1343
# Trial 162, Timestep 1344
# Trial 162, Timestep 1345
# Trial 162, Timestep 1346
# Trial 162, Timestep 1347
# Trial 162, Timestep 1348
# Trial 162, Timestep 1349
# Trial 162, Timestep 1350
# Trial 162, Timestep 1351
# Trial 162, Timestep 1352
# Trial 162, Timestep 1353
# Trial 162, Timestep 1354
# Trial 162, Timestep 1355
# Trial 162, Timestep 1356
# Trial 162, Timestep 1357
# Trial 162, Timestep 1358
# Trial 162, Timestep 1359
# Trial 162, Timestep 1360
# Trial 162, Timestep 1361
# Trial 162, Timestep 1362
# Trial 162, Timestep 1363
# Trial 162, Timestep 1364
# Trial 162, Timestep 1365
# Trial 162, Timestep 1366
# Trial 162, Timestep 1367
# Trial 162, Timestep 1368
# Trial 162, Timestep 1369
# Trial 162, Timestep 1370
# Trial 162, Timestep 1371
# Trial 162, Timestep 1372
# Trial 162, Timestep 1373
# Trial 162, Timestep 1374
# Trial 162, Timestep 1375
# Trial 162, Timestep 1376
# Trial 162, Timestep 1377
# Trial 162, Timestep 1378
# Trial 162, Timestep 1379
# Trial 162, Timestep 1380
# Trial 162, Timestep 1381
# Trial 162, Timestep 1382
# Trial 162, Timestep 1383
# Trial 162, Timestep 1384
# Trial 162, Timestep 1385
# Trial 162, Timestep 1386
# Trial 162, Timestep 1387
# Trial 162, Timestep 1388
# Trial 162, Timestep 1389
# Trial 162, Timestep 1390
# Trial 162, Timestep 1391
# Trial 162, Timestep 1392
# Trial 162, Timestep 1393
# Trial 162, Timestep 1394
# Trial 162, Timestep 1395
# Trial 162, Timestep 1396
# Trial 162, Timestep 1397
# Trial 162, Timestep 1398
# Trial 162, Timestep 1399
# Trial 162, Timestep 1400
# Trial 162, Timestep 1401
# Trial 162, Timestep 1402
# Trial 162, Timestep 1403
# Trial 162, Timestep 1404
# Trial 162, Timestep 1405
# Trial 162, Timestep 1406
# Trial 162, Timestep 1407
# Trial 162, Timestep 1408
# Trial 162, Timestep 1409
# Trial 162, Timestep 1410
# Trial 162, Timestep 1411
# Trial 162, Timestep 1412
# Trial 162, Timestep 1413
# Trial 162, Timestep 1414
# Trial 162, Timestep 1415
# Trial 162, Timestep 1416
# Trial 162, Timestep 1417
# Trial 162, Timestep 1418
# Trial 162, Timestep 1419
# Trial 162, Timestep 1420
# Trial 162, Timestep 1421
# Trial 162, Timestep 1422
# Trial 162, Timestep 1423
# Trial 162, Timestep 1424
# Trial 162, Timestep 1425
# Trial 162, Timestep 1426
# Trial 162, Timestep 1427
# Trial 162, Timestep 1428
# Trial 162, Timestep 1429
# Trial 162, Timestep 1430
# Trial 162, Timestep 1431
# Trial 162, Timestep 1432
# Trial 162, Timestep 1433
# Trial 162, Timestep 1434
# Trial 162, Timestep 1435
# Trial 162, Timestep 1436
# Trial 162, Timestep 1437
# Trial 163, Timestep 1487
# Trial 163, Timestep 1488
# Trial 163, Timestep 1489
# Trial 163, Timestep 1490
# Trial 163, Timestep 1491
# Trial 163, Timestep 1492
# Trial 163, Timestep 1493
# Trial 163, Timestep 1494
# Trial 163, Timestep 1495
# Trial 163, Timestep 1496
# Trial 163, Timestep 1497
# Trial 163, Timestep 1498
# Trial 163, Timestep 1499

# %%
# ###### Generate mp4 of fish swimming in Top down view along with reference trajectory for specified trials
# for trial_id in trial_ids:
#     # create plotter object
#     plotter = pv.Plotter()
#     # Open a mp4
#     plotter.open_movie(outputPath + f"Trial{trial_id}_topView.mp4", framerate = 100, quality=7)
#     # Iterate through timesteps and add frames
#     for i in range(timesteps):
#         print(f"Trial {trial_id}, Timestep {i}")
#         ### Make surface from desired reference trajectory
#         # Load data from database
#         conn = get_db_connection()
#         data = fetch_trial_data_singleTimestep(conn, trial_id, 1, start_timestep=i, num_timesteps=1)
#         conn.close()
#         timestep, simulation_time, input_data, output_data, state_data, y_ref, x_hat = data[0]
#         # Check shape of reference trajectory
#         uncenteredRefTraj=y_ref + refOffsets
#         # Turn reference trajectory from 40x1 to 20x2 array by taking every other point 
#         x_refs = uncenteredRefTraj[::2]
#         z_refs = uncenteredRefTraj[1::2]
#         referenceCurve = np.column_stack((x_refs, np.zeros(np.size(x_refs)), z_refs))
#         # print(np.shape(referenceCurve))
#         path = referenceCurve
#         offsetPath = np.copy(path)
#         offsetPath[:, 1] = offsetPath[:, 1] - 200
#         #### Draw Surface for reference trajectory
#         # Number of samples (in depth dir) and number of points along centerline 
#         nsamples = 5
#         ntraces = 20  

#         # Define the Z spacing of your 2D section
#         z_spacing = 50
#         # Create structured points draping down from the path
#         points = np.repeat(path, nsamples, axis=0)
#         # repeat the Z locations across
#         tp = np.arange(0, z_spacing * nsamples, z_spacing)
#         # Offset the Z locations 
#         tp = path[:, 1][:, None] - tp
#         points[:, 1] = tp.ravel()
#         #Make a StructuredGrid from the structured points
#         grid = pv.StructuredGrid()
#         grid.points = points
#         grid.dimensions = nsamples, ntraces, 1

#         # Add the data array - note the ordering
#         grid["values"] = np.ones((nsamples, ntraces), dtype=np.float64).ravel(order="F")

#         # load mesh from .vtu file in tempMeshPath
#         mesh = pv.read(tempMeshPath + f"Trial{trial_id}_step{i}.vtu")
#         # add fish mesh to plotter
#         plotter.add_mesh(mesh, show_scalar_bar=False, name = 'mesh') # add the fish body
#         plotter.add_mesh(grid, clim=[-1, 1],show_scalar_bar=False, name = 'reference', opacity=0.5)
#         # add reference trajectory to plotter with thickness of 5 and large markers
#         plotter.add_mesh(pv.PolyData(offsetPath), color='orange', line_width=5, name = 'refPath', opacity=1, render_points_as_spheres=True, point_size=10)
#         # Set the camera position - Top View Down
#         plotter.camera_position = 'yz'
#         plotter.camera.roll = 180
#         plotter.camera.azimuth = 90 #
#         plotter.camera.elevation = 90 #50
#         plotter.enable_parallel_projection()

#         # write frame to gif
#         plotter.write_frame()
#     # Close the gif
#     plotter.close()
